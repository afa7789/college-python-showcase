# %% [markdown]
# ## Using Keras to Build and Train Neural Networks

# %% [markdown]
# In this exercise we will use a neural network to predict diabetes using the Pima Diabetes Dataset.  We will start by training a Random Forest to get a performance baseline.  Then we will use the Keras package to quickly build and train a neural network and compare the performance.  We will see how different network structures affect the performance, training time, and level of overfitting (or underfitting).
#
# ## UCI Pima Diabetes Dataset
#
# * UCI ML Repositiory (http://archive.ics.uci.edu/ml/datasets/Pima+Indians+Diabetes)
#
#
# ### Attributes: (all numeric-valued)
#    1. Number of times pregnant
#    2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#    3. Diastolic blood pressure (mm Hg)
#    4. Triceps skin fold thickness (mm)
#    5. 2-Hour serum insulin (mu U/ml)
#    6. Body mass index (weight in kg/(height in m)^2)
#    7. Diabetes pedigree function
#    8. Age (years)
#    9. Class variable (0 or 1)

# %% [markdown]
# The UCI Pima Diabetes Dataset which has 8 numerical predictors and a binary outcome.

# %%
#Preliminaries

from __future__ import absolute_import, division, print_function  # Python 2/3 compatibility

import warnings
warnings.filterwarnings("ignore")


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score, roc_curve, accuracy_score
from sklearn.ensemble import RandomForestClassifier

import seaborn as sns

# %matplotlib inline

# %%
## Import Keras objects for Deep Learning

from  tensorflow.keras.models  import Sequential
from  keras.models import K
from  tensorflow.keras.layers import Input,Flatten, Dropout, BatchNormalization
from  tensorflow.keras.layers import Dense

from  tensorflow.keras.optimizers import Adam, SGD, RMSprop

# %%
## Load in the data set (Internet Access needed)

##url = "http://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data"
names = ["times_pregnant", "glucose_tolerance_test", "blood_pressure", "skin_thickness", "insulin", 
         "bmi", "pedigree_function", "age", "has_diabetes"]
diabetes_df = pd.read_csv('pima-indians-diabetes.data', names=names)

# %%
# Take a peek at the data -- if there are lots of "NaN" you may have internet connectivity issues
print(diabetes_df.shape)
diabetes_df.sample(5)
# Out:
# (768, 9)
#      times_pregnant  glucose_tolerance_test  blood_pressure  skin_thickness  \
# 562               1                      87              68              34
# 736               0                     126              86              27
# 2                 8                     183              64               0
# 71                5                     139              64              35
# 537               0                      57              60               0
#
#      insulin   bmi  pedigree_function  age  has_diabetes
# 562       77  37.6              0.401   24             0
# 736      120  27.4              0.515   21             0
# 2          0  23.3              0.672   32             1
# 71       140  28.6              0.411   26             0
# 537        0  21.7              0.735   67             0

# %%
X = diabetes_df.iloc[:, :-1].values
y = diabetes_df["has_diabetes"].values

# %%
# Split the data to Train, and Test (75%, 25%)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=11111)

# %%
np.mean(y), np.mean(1-y)
# Out:
# (0.3489583333333333, 0.6510416666666666)

# %% [markdown]
# Above, we see that about 35% of the patients in this dataset have diabetes, while 65% do not.  This means we can get an accuracy of 65% without any model - just declare that no one has diabetes. We will calculate the ROC-AUC score to evaluate performance of our model, and also look at the accuracy as well to see if we improved upon the 65% accuracy.
# ## Exercise: Get a baseline performance using Random Forest
# To begin, and get a baseline for classifier performance:
# 1. Train a Random Forest model with 200 trees on the training data.
# 2. Calculate the accuracy and roc_auc_score of the predictions.

# %%
## Train the RF Model
rf_model = RandomForestClassifier(n_estimators=200)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
# Make predictions on the test set - both "hard" predictions, and the scores (percent of trees voting yes)
y_pred_class_rf = rf_model.predict(X_test)
y_pred_prob_rf = rf_model.predict_proba(X_test)


print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_rf)))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_rf[:,1])))
# Out:
# accuracy is 0.781
# roc-auc is 0.837

# %%
def plot_roc(y_test, y_pred, model_name):
    fpr, tpr, thr = roc_curve(y_test, y_pred)
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.plot(fpr, tpr, 'k-')
    ax.plot([0, 1], [0, 1], 'k--', linewidth=.5)  # roc curve for random model
    ax.grid(True)
    ax.set(title='ROC Curve for {} on PIMA diabetes problem'.format(model_name),
           xlim=[-0.01, 1.01], ylim=[-0.01, 1.01])


plot_roc(y_test, y_pred_prob_rf[:, 1], 'RF')

# %% [markdown]
# ## Build a Single Hidden Layer Neural Network
#
# We will use the Sequential model to quickly build a neural network.  Our first network will be a single layer network.  We have 8 variables, so we set the input shape to 8.  Let's start by having a single hidden layer with 12 nodes.

# %%
## First let's normalize the data
## This aids the training of neural nets by providing numerical stability
## Random Forest does not need this as it finds a split only, as opposed to performing matrix multiplications


normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# %%
# Define the Model 
# Input size is 8-dimensional
# 1 hidden layer, 12 hidden nodes, sigmoid activation
# Final layer has just one node with a sigmoid activation (standard for binary classification)

model_1 = Sequential([
    Dense(12, input_shape=(8,), activation="relu"),
    Dense(1, activation="sigmoid")
])

# %%
#  This is a nice tool to view the model you have created and count the parameters

model_1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 12)                108
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 13
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Comprehension question:
# Why do we have 121 parameters?  Does that make sense?
#
#
# Let's fit our model for 200 epochs.

# %%
# Fit(Train) the Model

# Compile the model with Optimizer, Loss Function and Metrics
# Roc-Auc is not available in Keras as an off the shelf metric yet, so we will skip it here.

model_1.compile(SGD(lr = .003), "binary_crossentropy", metrics=["accuracy"])
run_hist_1 = model_1.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=200)
# the fit function returns the run history. 
# It is very convenient, as it contains information about the model fit, iterations etc.
# Out:
# l_accuracy: 0.7188
# Epoch 61/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5252 - accuracy: 0.7188 - val_loss: 0.5527 - val_accuracy: 0.7188
# Epoch 62/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5242 - accuracy: 0.7222 - val_loss: 0.5520 - val_accuracy: 0.7188
# Epoch 63/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.7240 - val_loss: 0.5512 - val_accuracy: 0.7188
# Epoch 64/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.7257 - val_loss: 0.5505 - val_accuracy: 0.7135
# Epoch 65/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5214 - accuracy: 0.7257 - val_loss: 0.5497 - val_accuracy: 0.7083
# Epoch 66/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5204 - accuracy: 0.7274 - val_loss: 0.5490 - val_accuracy: 0.7031
# Epoch 67/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5196 - accuracy: 0.7326 - val_loss: 0.5483 - val_accuracy: 0.7031
# Epoch 68/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.7326 - val_loss: 0.5476 - val_accuracy: 0.7031
# Epoch 69/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5178 - accuracy: 0.7309 - val_loss: 0.5469 - val_accuracy: 0.7031
# Epoch 70/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5170 - accuracy: 0.7326 - val_loss: 0.5463 - val_accuracy: 0.7031
# Epoch 71/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5162 - accuracy: 0.7344 - val_loss: 0.5456 - val_accuracy: 0.7135
# Epoch 72/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.7760 - val_loss: 0.5142 - val_accuracy: 0.7396
# Epoch 167/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4664 - accuracy: 0.7760 - val_loss: 0.5141 - val_accuracy: 0.7448
# Epoch 168/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4661 - accuracy: 0.7760 - val_loss: 0.5139 - val_accuracy: 0.7448
# Epoch 169/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.7760 - val_loss: 0.5138 - val_accuracy: 0.7448
# Epoch 170/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4655 - accuracy: 0.7743 - val_loss: 0.5136 - val_accuracy: 0.7448
# Epoch 171/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7743 - val_loss: 0.5135 - val_accuracy: 0.7448
# Epoch 172/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4649 - accuracy: 0.7760 - val_loss: 0.5133 - val_accuracy: 0.7500
# Epoch 173/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4646 - accuracy: 0.7760 - val_loss: 0.5132 - val_accuracy: 0.7500
# Epoch 174/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.7760 - val_loss: 0.5131 - val_accuracy: 0.7552
# Epoch 175/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4641 - accuracy: 0.7760 - val_loss: 0.5129 - val_accuracy: 0.7552
# Epoch 176/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4638 - accuracy: 0.7795 - val_loss: 0.5128 - val_accuracy: 0.7552
# Epoch 177/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4635 - accuracy: 0.7795 - val_loss: 0.5127 - val_accuracy: 0.7552
# Epoch 178/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.7795 - val_loss: 0.5125 - val_accuracy: 0.7552
# Epoch 179/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4630 - accuracy: 0.7778 - val_loss: 0.5124 - val_accuracy: 0.7552
# Epoch 180/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4628 - accuracy: 0.7778 - val_loss: 0.5123 - val_accuracy: 0.7552
# Epoch 181/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.7778 - val_loss: 0.5122 - val_accuracy: 0.7604
# Epoch 182/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4623 - accuracy: 0.7760 - val_loss: 0.5120 - val_accuracy: 0.7604
# Epoch 183/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4620 - accuracy: 0.7760 - val_loss: 0.5119 - val_accuracy: 0.7604
# Epoch 184/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.7760 - val_loss: 0.5118 - val_accuracy: 0.7604
# Epoch 185/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4615 - accuracy: 0.7760 - val_loss: 0.5117 - val_accuracy: 0.7604
# Epoch 186/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4613 - accuracy: 0.7760 - val_loss: 0.5116 - val_accuracy: 0.7604
# Epoch 187/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4610 - accuracy: 0.7760 - val_loss: 0.5115 - val_accuracy: 0.7604
# Epoch 188/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4608 - accuracy: 0.7760 - val_loss: 0.5114 - val_accuracy: 0.7604
# Epoch 189/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4605 - accuracy: 0.7743 - val_loss: 0.5113 - val_accuracy: 0.7604
# Epoch 190/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4603 - accuracy: 0.7743 - val_loss: 0.5112 - val_accuracy: 0.7604
# Epoch 191/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.7743 - val_loss: 0.5111 - val_accuracy: 0.7604
# Epoch 192/200
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4599 - accuracy: 0.7726 - val_loss: 0.5110 - val_accuracy: 0.7604
# Epoch 193/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.7726 - val_loss: 0.5109 - val_accuracy: 0.7604
# Epoch 194/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.7708 - val_loss: 0.5108 - val_accuracy: 0.7604
# Epoch 195/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.7708 - val_loss: 0.5107 - val_accuracy: 0.7604
# Epoch 196/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.7726 - val_loss: 0.5107 - val_accuracy: 0.7604
# Epoch 197/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4589 - accuracy: 0.7708 - val_loss: 0.5106 - val_accuracy: 0.7604
# Epoch 198/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4587 - accuracy: 0.7708 - val_loss: 0.5105 - val_accuracy: 0.7604
# Epoch 199/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4585 - accuracy: 0.7708 - val_loss: 0.5104 - val_accuracy: 0.7604
# Epoch 200/200
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4583 - accuracy: 0.7708 - val_loss: 0.5104 - val_accuracy: 0.7604

# %%
## Like we did for the Random Forest, we generate two kinds of predictions
#  One is a hard decision, the other is a probabilitistic score.

y_pred_class_nn_1 = model_1.predict_classes(X_test_norm)
y_pred_prob_nn_1 = model_1.predict(X_test_norm)

# %%
# Let's check out the outputs to get a feel for how keras apis work.
y_pred_class_nn_1[:10]
# Out:
# array([[0],
#        [1],
#        [0],
#        [0],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [0]], dtype=int32)

# %%
y_pred_prob_nn_1[:10]
# Out:
# array([[0.4830399 ],
#        [0.6790826 ],
#        [0.42775863],
#        [0.29631764],
#        [0.1978108 ],
#        [0.55181986],
#        [0.03841603],
#        [0.4671836 ],
#        [0.796749  ],
#        [0.21680099]], dtype=float32)

# %%
# Print model performance and plot the roc curve
print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_1)))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_1)))

plot_roc(y_test, y_pred_prob_nn_1, 'NN')
# Out:
# accuracy is 0.760
# roc-auc is 0.811

# %% [markdown]
# There may be some variation in exact numbers due to randomness, but you should get results in the same ballpark as the Random Forest - between 75% and 85% accuracy, between .8 and .9 for AUC.

# %% [markdown]
# Let's look at the `run_hist_1` object that was created, specifically its `history` attribute.

# %%
run_hist_1.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Let's plot the training loss and the validation loss over the different epochs and see how it looks.

# %%
fig, ax = plt.subplots()
ax.plot(run_hist_1.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.legend()

# %% [markdown]
# Looks like the losses are still going down on both the training set and the validation set.  This suggests that the model might benefit from further training.  Let's train the model a little more and see what happens. Note that it will pick up from where it left off. Train for 1000 more epochs.

# %%
## Note that when we call "fit" again, it picks up where it left off
run_hist_1b = model_1.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=1000)
# Out:
# ===================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.8003 - val_loss: 0.5166 - val_accuracy: 0.7760
# Epoch 864/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.8003 - val_loss: 0.5166 - val_accuracy: 0.7760
# Epoch 865/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.8003 - val_loss: 0.5166 - val_accuracy: 0.7760
# Epoch 866/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 867/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4213 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 868/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 869/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 870/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 871/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 872/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 873/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 874/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 875/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 876/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5167 - val_accuracy: 0.7760
# Epoch 877/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 878/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 879/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 880/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 881/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 882/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.6075 - accuracy: 0.6818/18 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 883/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4210 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 884/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 885/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8003 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 886/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 887/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 888/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 889/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 890/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 891/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 892/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 893/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 894/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5169 - val_accuracy: 0.7760
# Epoch 895/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 896/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 897/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 898/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 899/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 900/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 901/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 902/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 903/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 904/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5170 - val_accuracy: 0.7760
# Epoch 905/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 906/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 907/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 908/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 909/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 910/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 911/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 912/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 913/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 914/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 915/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5171 - val_accuracy: 0.7760
# Epoch 916/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 917/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 918/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 919/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 920/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 921/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 922/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 923/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 924/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4205 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 925/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 926/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 927/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5172 - val_accuracy: 0.7760
# Epoch 928/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 929/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 930/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 931/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 932/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 933/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 934/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 935/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 936/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 937/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 938/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5173 - val_accuracy: 0.7760
# Epoch 939/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4203 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 940/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 941/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 942/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 943/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 944/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 945/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 946/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 947/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 948/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8003 - val_loss: 0.5174 - val_accuracy: 0.7760
# Epoch 949/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7760
# Epoch 950/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7760
# Epoch 951/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7760
# Epoch 952/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7760
# Epoch 953/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7760
# Epoch 954/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 955/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 956/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 957/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 958/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 959/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5175 - val_accuracy: 0.7812
# Epoch 960/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 961/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4200 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 962/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8021 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 963/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 964/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 965/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 966/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 967/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4199 - accuracy: 0.8021 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 968/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 969/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.8003 - val_loss: 0.5176 - val_accuracy: 0.7812
# Epoch 970/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.8003 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 971/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 972/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.8003 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 973/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 974/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 975/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 976/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4198 - accuracy: 0.8021 - val_loss: 0.5177 - val_accuracy: 0.7812
# Epoch 977/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.8021 - val_loss: 0.5178 - val_accuracy: 0.7812
# Epoch 978/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.8021 - val_loss: 0.5178 - val_accuracy: 0.7812
# Epoch 979/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.8021 - val_loss: 0.5179 - val_accuracy: 0.7812
# Epoch 980/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8021 - val_loss: 0.5179 - val_accuracy: 0.7812
# Epoch 981/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4196 - accuracy: 0.8021 - val_loss: 0.5180 - val_accuracy: 0.7812
# Epoch 982/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4196 - accuracy: 0.8021 - val_loss: 0.5180 - val_accuracy: 0.7812
# Epoch 983/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4196 - accuracy: 0.8021 - val_loss: 0.5181 - val_accuracy: 0.7812
# Epoch 984/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8021 - val_loss: 0.5181 - val_accuracy: 0.7812
# Epoch 985/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.8021 - val_loss: 0.5181 - val_accuracy: 0.7812
# Epoch 986/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4196 - accuracy: 0.8021 - val_loss: 0.5182 - val_accuracy: 0.7812
# Epoch 987/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.8021 - val_loss: 0.5182 - val_accuracy: 0.7812
# Epoch 988/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4195 - accuracy: 0.8021 - val_loss: 0.5183 - val_accuracy: 0.7812
# Epoch 989/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4194 - accuracy: 0.8021 - val_loss: 0.5183 - val_accuracy: 0.7812
# Epoch 990/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.8021 - val_loss: 0.5183 - val_accuracy: 0.7812
# Epoch 991/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.8021 - val_loss: 0.5184 - val_accuracy: 0.7812
# Epoch 992/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4194 - accuracy: 0.8021 - val_loss: 0.5184 - val_accuracy: 0.7812
# Epoch 993/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.8021 - val_loss: 0.5184 - val_accuracy: 0.7812
# Epoch 994/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8021 - val_loss: 0.5185 - val_accuracy: 0.7812
# Epoch 995/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4193 - accuracy: 0.8021 - val_loss: 0.5185 - val_accuracy: 0.7812
# Epoch 996/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8021 - val_loss: 0.5185 - val_accuracy: 0.7812
# Epoch 997/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8021 - val_loss: 0.5186 - val_accuracy: 0.7812
# Epoch 998/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8021 - val_loss: 0.5186 - val_accuracy: 0.7812
# Epoch 999/1000
#  1/18 [>.............................] - ETA: 0s - loss: 0.2744 - accuracy: 0.8718/18 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8021 - val_loss: 0.5187 - val_accuracy: 0.7812
# Epoch 1000/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8021 - val_loss: 0.5187 - val_accuracy: 0.7812

# %%
n = len(run_hist_1.history["loss"])
m = len(run_hist_1b.history['loss'])
fig, ax = plt.subplots(figsize=(16, 8))

ax.plot(range(n), run_hist_1.history["loss"],'r', marker='.', label="Train Loss - Run 1")
ax.plot(range(n, n+m), run_hist_1b.history["loss"], 'hotpink', marker='.', label="Train Loss - Run 2")

ax.plot(range(n), run_hist_1.history["val_loss"],'b', marker='.', label="Validation Loss - Run 1")
ax.plot(range(n, n+m), run_hist_1b.history["val_loss"], 'LightSkyBlue', marker='.',  label="Validation Loss - Run 2")

ax.legend()

# %% [markdown]
# Note that this graph begins where the other left off.  While the training loss is still going down, it looks like the validation loss has stabilized (or even gotten worse!).  This suggests that our network will not benefit from further training.  What is the appropriate number of epochs?

# %% [markdown]
# ## Exercise
# Now it's your turn.  Do the following in the cells below:
# - Build a model with two hidden layers, each with 6 nodes
# - Use the "relu" activation function for the hidden layers, and "sigmoid" for the final layer
# - Use a learning rate of .003 and train for 1500 epochs
# - Graph the trajectory of the loss functions, accuracy on both train and test set
# - Plot the roc curve for the predictions
#
# Experiment with different learning rates, numbers of epochs, and network structures

# %%
model_2 = Sequential([
    Dense(6, input_shape=(8,), activation="relu"),
    Dense(6, input_shape=(8,), activation="relu"),
    Dense(1, activation="sigmoid")
])

# %%
# Fit(Train) the Model

# Compile the model with Optimizer, Loss Function and Metrics
# Roc-Auc is not available in Keras as an off the shelf metric yet, so we will skip it here.

model_2.compile(SGD(lr = .003), "binary_crossentropy", metrics=["accuracy"])
run_hist_2 = model_2.fit(X_train_norm, y_train, validation_data=(X_test_norm, y_test), epochs=1500)
# the fit function returns the run history. 
# It is very convenient, as it contains information about the model fit, iterations etc.
# Out:
# /1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4181 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1364/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1365/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.8056 - val_loss: 0.5389 - val_accuracy: 0.7448
# Epoch 1366/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1367/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.8073 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1368/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1369/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4179 - accuracy: 0.8090 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1370/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4179 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1371/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4179 - accuracy: 0.8056 - val_loss: 0.5390 - val_accuracy: 0.7448
# Epoch 1372/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1373/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4178 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1374/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8073 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1375/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1376/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1377/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1378/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4177 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1379/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1380/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1381/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8056 - val_loss: 0.5391 - val_accuracy: 0.7448
# Epoch 1382/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.
1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8090 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1481/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8090 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1482/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.8108 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1483/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8108 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1484/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8125 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1485/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8090 - val_loss: 0.5392 - val_accuracy: 0.7448
# Epoch 1486/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1487/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8090 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1488/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8125 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1489/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8125 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1490/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1491/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8125 - val_loss: 0.5394 - val_accuracy: 0.7448
# Epoch 1492/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8108 - val_loss: 0.5394 - val_accuracy: 0.7448
# Epoch 1493/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1494/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1495/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8125 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1496/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8090 - val_loss: 0.5394 - val_accuracy: 0.7448
# Epoch 1497/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1498/1500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4154 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1499/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8125 - val_loss: 0.5393 - val_accuracy: 0.7448
# Epoch 1500/1500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4153 - accuracy: 0.8108 - val_loss: 0.5393 - val_accuracy: 0.7448

# %%
## Like we did for the Random Forest, we generate two kinds of predictions
#  One is a hard decision, the other is a probabilitistic score.

y_pred_class_nn_2 = model_2.predict_classes(X_test_norm)
y_pred_prob_nn_2 = model_2.predict(X_test_norm)

print('accuracy is {:.3f}'.format(accuracy_score(y_test,y_pred_class_nn_2)))
print('roc-auc is {:.3f}'.format(roc_auc_score(y_test,y_pred_prob_nn_2)))

plot_roc(y_test, y_pred_prob_nn_2, 'NN')
# Out:
# accuracy is 0.745
# roc-auc is 0.805

# %%
run_hist_2 .history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
fig, ax = plt.subplots()
ax.plot(run_hist_2.history["loss"],'r', marker='.', label="Train Loss")
ax.plot(run_hist_2.history["val_loss"],'b', marker='.', label="Validation Loss")
ax.plot(run_hist_2.history["accuracy"],'g', marker='.', label="Accuracy")
ax.plot(run_hist_2.history["val_accuracy"],'#232323', marker='.', label="Validation Accuracy")

ax.legend()
